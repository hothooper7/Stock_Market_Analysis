# %%
import pandas as pd
import numpy as np
import datetime as dt
import json
import nltk
import pprint
import re
import requests
import statsmodels.api as sm
import yfinance as yf
from sqlalchemy import create_engine
import psycopg2
from config import db_password

import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Note: Aim of this work is to build a Deep Learning LSTM Model to predict stock data

# %% [markdown]
# ## Data retrieval

# %%
# Connect with Amazon RDS Database Instance 

db_string = f'postgresql://postgres:{db_password}@myclassdb-01.cd80yqfjmzyg.us-east-1.rds.amazonaws.com/stock_market'

engine = create_engine(db_string)

# %%
# Retrieve data (here for 'AAPL')

df = pd.read_sql("SELECT * FROM stocks WHERE ticker = 'AAPL' ORDER BY date", engine)

# %%
# Check for dataset quality, e.g., missing values etc.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10486 entries, 0 to 10485
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ticker    10486 non-null  object
#  1   date      10486 non-null  object
#  2   code      10486 non-null  object
#  3   open      10486 non-null  float64
#  4   high      10486 non-null  float64
#  5   low       10486 non-null  float64
#  6   close     10486 non-null  float64
#  7   adjclose  10486 non-null  float64
#  8   volume    10486 non-null  float64
# dtypes: float64(6), object(3)
# memory usage: 737.4+ KB

# %%
df.drop(columns = ['ticker', 'code'], inplace=True)

# %%
df
# Out:
#              date        open        high         low       close    adjclose  \
# 0      1980-12-12    0.128348    0.128906    0.128348    0.128348    0.100178
# 1      1980-12-15    0.122210    0.122210    0.121652    0.121652    0.094952
# 2      1980-12-16    0.113281    0.113281    0.112723    0.112723    0.087983
# 3      1980-12-17    0.115513    0.116071    0.115513    0.115513    0.090160
# 4      1980-12-18    0.118862    0.119420    0.118862    0.118862    0.092774
# ...           ...         ...         ...         ...         ...         ...
# 10481  2022-07-11  145.669998  146.639999  143.779999  144.869995  144.869995
# 10482  2022-07-12  145.759995  148.449997  145.050003  145.860001  145.860001
# 10483  2022-07-13  142.990005  146.449997  142.119995  145.490005  145.490005
# 10484  2022-07-14  144.080002  148.949997  143.250000  148.470001  148.470001
# 10485  2022-07-15  149.779999  150.860001  148.199997  150.169998  150.169998
#
#             volume
# 0      469033600.0
# 1      175884800.0
# 2      105728000.0
# 3       86441600.0
# 4       73449600.0
# ...            ...
# 10481   63141600.0
# 10482   77588800.0
# 10483   71185600.0
# 10484   78140700.0
# 10485   76030800.0
#
# [10486 rows x 7 columns]

# %%
# Date format needs a change to date time
df['date'] = pd.to_datetime(df['date'])
df.set_index('date', inplace = True)

df
# Out:
#                   open        high         low       close    adjclose  \
# date
# 1980-12-12    0.128348    0.128906    0.128348    0.128348    0.100178
# 1980-12-15    0.122210    0.122210    0.121652    0.121652    0.094952
# 1980-12-16    0.113281    0.113281    0.112723    0.112723    0.087983
# 1980-12-17    0.115513    0.116071    0.115513    0.115513    0.090160
# 1980-12-18    0.118862    0.119420    0.118862    0.118862    0.092774
# ...                ...         ...         ...         ...         ...
# 2022-07-11  145.669998  146.639999  143.779999  144.869995  144.869995
# 2022-07-12  145.759995  148.449997  145.050003  145.860001  145.860001
# 2022-07-13  142.990005  146.449997  142.119995  145.490005  145.490005
# 2022-07-14  144.080002  148.949997  143.250000  148.470001  148.470001
# 2022-07-15  149.779999  150.860001  148.199997  150.169998  150.169998
#
#                  volume
# date
# 1980-12-12  469033600.0
# 1980-12-15  175884800.0
# 1980-12-16  105728000.0
# 1980-12-17   86441600.0
# 1980-12-18   73449600.0
# ...                 ...
# 2022-07-11   63141600.0
# 2022-07-12   77588800.0
# 2022-07-13   71185600.0
# 2022-07-14   78140700.0
# 2022-07-15   76030800.0
#
# [10486 rows x 6 columns]

# %%
# Check for null values
df.isnull().count()
# Out:
# open        10486
# high        10486
# low         10486
# close       10486
# adjclose    10486
# volume      10486
# dtype: int64

# %% [markdown]
# ## Prepare and check data

# %%
df_train = df[8600:10000]

# %%
df_train.shape
# Out:
# (1400, 6)

# %%
df_test = df[10000:]

# %%
df_test.shape
# Out:
# (486, 6)

# %%
# Plot Adjusted Close (training set)

df_train.adjclose.plot(x="date", y="adjclose", figsize = (16, 8), title = "Adjusted Close values of training data")
# Out:
# <AxesSubplot:title={'center':'Adjusted Close values of training data'}, xlabel='date'>

# %%
df_train.volume.plot(x="date", y="volume", figsize = (16, 8), title = "Volume traded in raining data")
# Out:
# <AxesSubplot:title={'center':'Volume traded in raining data'}, xlabel='date'>

# %% [markdown]
# ## Preprocess Data

# %%
training_set = df_train.iloc[:, 4:5].values

# %%
# Normalizing data, scale between 0 and 1:

from sklearn.preprocessing import MinMaxScaler

sc = MinMaxScaler(feature_range=(0, 1))

training_set_scaled = sc.fit_transform(training_set)
# training_set_scaled = sc.fit_transform(np.array(df).reshape(-1, 1)

# %%
X_train = []
y_train = []

for i in range(60, 1400):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])

X_train, y_train = np.array(X_train), np.array(y_train)

# %% [markdown]
# ## LSTM Model

# %%
model = tf.keras.models.Sequential()

model.add(tf.keras.layers.LSTM(units=50, return_sequences=True, 
                               input_shape=(X_train.shape[1], 1)))

model.add(tf.keras.layers.Dropout(0.2))

model.add(tf.keras.layers.LSTM(units=50, return_sequences=True))

model.add(tf.keras.layers.Dropout(0.2))

model.add(tf.keras.layers.LSTM(units=50, return_sequences=True))

model.add(tf.keras.layers.Dropout(0.2))

model.add(tf.keras.layers.LSTM(units=50))

model.add(tf.keras.layers.Dropout(0.2))

model.add(tf.keras.layers.Dense(units=1))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60, 50)            10400
#
#  dropout (Dropout)           (None, 60, 50)            0
#
#  lstm_1 (LSTM)               (None, 60, 50)            20200
#
#  dropout_1 (Dropout)         (None, 60, 50)            0
#
#  lstm_2 (LSTM)               (None, 60, 50)            20200
#
#  dropout_2 (Dropout)         (None, 60, 50)            0
#
#  lstm_3 (LSTM)               (None, 50)                20200
#
#  dropout_3 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 71,051
# Trainable params: 71,051
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
model01 = model.fit(X_train, y_train, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 42/42 [==============================] - 9s 82ms/step - loss: 0.0111
# Epoch 2/100
# 42/42 [==============================] - 3s 65ms/step - loss: 0.0019
# Epoch 3/100
# 42/42 [==============================] - 3s 63ms/step - loss: 0.0015
# Epoch 4/100
# 42/42 [==============================] - 3s 64ms/step - loss: 0.0014
# Epoch 5/100
# 42/42 [==============================] - 3s 63ms/step - loss: 0.0011
# Epoch 6/100
# 42/42 [==============================] - 3s 64ms/step - loss: 0.0011
# Epoch 7/100
# 42/42 [==============================] - 3s 63ms/step - loss: 0.0010
# Epoch 8/100
# 42/42 [==============================] - 3s 64ms/step - loss: 7.9292e-04
# Epoch 9/100
# 42/42 [==============================] - 3s 66ms/step - loss: 8.1418e-04
# Epoch 10/100
# 42/42 [==============================] - 3s 65ms/step - loss: 8.3947e-04
# Epoch 11/100
# 42/42 [==============================] - 3s 64ms/step - loss: 7.5583e-04
# Epoch 12/100
# 42/42 [==============================] - 3s 63ms/step - loss: 7.9905e-04
# Epoch 13/100
# 42/42 [==============================] - 3s 64ms/step - loss: 8.2294e-04
# Epoch 14/100
# 42/42 [==============================] - 3s 64ms/step - loss: 7.5641e-04
# Epoch 15/100
# 42/42 [==============================] - 3s 64ms/step - loss: 7.2075e-04
# Epoch 16/100
# 42/42 [==============================] - 3s 64ms/step - loss: 6.0560e-04
# Epoch 17/100
# 42/42 [==============================] - 3s 65ms/step - loss: 6.9402e-04
# Epoch 18/100
# 42/42 [==============================] - 3s 64ms/step - loss: 5.6536e-04
# Epoch 19/100
# 42/42 [==============================] - 3s 66ms/step - loss: 5.4271e-04
# Epoch 20/100
# 42/42 [==============================] - 3s 64ms/step - loss: 6.8128e-04
# Epoch 21/100
# 42/42 [==============================] - 3s 66ms/step - loss: 6.2291e-04
# Epoch 22/100
# 42/42 [==============================] - 3s 65ms/step - loss: 6.5211e-04
# Epoch 23/100
# 42/42 [==============================] - 3s 64ms/step - loss: 5.3753e-04
# Epoch 24/100
# 42/42 [==============================] - 3s 65ms/step - loss: 6.0768e-04
# Epoch 25/100
# 42/42 [==============================] - 3s 65ms/step - loss: 6.2853e-04
# Epoch 26/100
# 42/42 [==============================] - 3s 65ms/step - loss: 5.0341e-04
# Epoch 27/100
# 42/42 [==============================] - 3s 65ms/step - loss: 8.9513e-04
# Epoch 28/100
# 42/42 [==============================] - 3s 65ms/step - loss: 6.3255e-04
# Epoch 29/100
# 42/42 [==============================] - 3s 65ms/step - loss: 5.0754e-04
# Epoch 30/100
# 42/42 [==============================] - 3s 66ms/step - loss: 5.0342e-04
# Epoch 31/100
# 42/42 [==============================] - 3s 67ms/step - loss: 7.7259e-04
# Epoch 32/100
# 42/42 [==============================] - 3s 69ms/step - loss: 4.9629e-04
# Epoch 33/100
# 42/42 [==============================] - 3s 66ms/step - loss: 5.3336e-04
# Epoch 34/100
# 42/42 [==============================] - 3s 68ms/step - loss: 6.1814e-04
# Epoch 35/100
# 42/42 [==============================] - 3s 66ms/step - loss: 5.4117e-04
# Epoch 36/100
# 42/42 [==============================] - 3s 68ms/step - loss: 4.5809e-04
# Epoch 37/100
# 42/42 [==============================] - 3s 68ms/step - loss: 4.9967e-04
# Epoch 38/100
# 42/42 [==============================] - 3s 67ms/step - loss: 4.9410e-04
# Epoch 39/100
# 42/42 [==============================] - 3s 66ms/step - loss: 5.8154e-04
# Epoch 40/100
# 42/42 [==============================] - 3s 69ms/step - loss: 5.1796e-04
# Epoch 41/100
# 42/42 [==============================] - 3s 67ms/step - loss: 4.6211e-04
# Epoch 42/100
# 42/42 [==============================] - 3s 71ms/step - loss: 4.8832e-04
# Epoch 43/100
# 42/42 [==============================] - 3s 70ms/step - loss: 4.7175e-04
# Epoch 44/100
# 42/42 [==============================] - 3s 67ms/step - loss: 4.8502e-04
# Epoch 45/100
# 42/42 [==============================] - 3s 66ms/step - loss: 3.7922e-04
# Epoch 46/100
# 42/42 [==============================] - 3s 67ms/step - loss: 4.0126e-04
# Epoch 47/100
# 42/42 [==============================] - 3s 68ms/step - loss: 5.5172e-04
# Epoch 48/100
# 42/42 [==============================] - 3s 66ms/step - loss: 4.3389e-04
# Epoch 49/100
# 42/42 [==============================] - 3s 67ms/step - loss: 5.3568e-04
# Epoch 50/100
# 42/42 [==============================] - 3s 67ms/step - loss: 4.6426e-04
# Epoch 51/100
# 42/42 [==============================] - 3s 67ms/step - loss: 4.7452e-04
# Epoch 52/100
# 42/42 [==============================] - 3s 66ms/step - loss: 3.9338e-04
# Epoch 53/100
# 42/42 [==============================] - 3s 66ms/step - loss: 3.4498e-04
# Epoch 54/100
# 42/42 [==============================] - 3s 66ms/step - loss: 5.0073e-04
# Epoch 55/100
# 42/42 [==============================] - 3s 67ms/step - loss: 3.8550e-04
# Epoch 56/100
# 42/42 [==============================] - 3s 70ms/step - loss: 3.4694e-04
# Epoch 57/100
# 42/42 [==============================] - 3s 70ms/step - loss: 3.8349e-04
# Epoch 58/100
# 42/42 [==============================] - 3s 69ms/step - loss: 3.5011e-04
# Epoch 59/100
# 42/42 [==============================] - 3s 67ms/step - loss: 3.2620e-04
# Epoch 60/100
# 42/42 [==============================] - 3s 67ms/step - loss: 3.4810e-04
# Epoch 61/100
# 42/42 [==============================] - 3s 68ms/step - loss: 4.1046e-04
# Epoch 62/100
# 42/42 [==============================] - 3s 69ms/step - loss: 3.0074e-04
# Epoch 63/100
# 42/42 [==============================] - 3s 71ms/step - loss: 3.3004e-04
# Epoch 64/100
# 42/42 [==============================] - 3s 70ms/step - loss: 3.7359e-04
# Epoch 65/100
# 42/42 [==============================] - 3s 69ms/step - loss: 3.2127e-04
# Epoch 66/100
# 42/42 [==============================] - 3s 67ms/step - loss: 3.3027e-04
# Epoch 67/100
# 42/42 [==============================] - 3s 68ms/step - loss: 3.1063e-04
# Epoch 68/100
# 42/42 [==============================] - 3s 68ms/step - loss: 3.1289e-04
# Epoch 69/100
# 42/42 [==============================] - 3s 67ms/step - loss: 3.5505e-04
# Epoch 70/100
# 42/42 [==============================] - 3s 68ms/step - loss: 2.8539e-04
# Epoch 71/100
# 42/42 [==============================] - 3s 68ms/step - loss: 3.4773e-04
# Epoch 72/100
# 42/42 [==============================] - 3s 70ms/step - loss: 3.0784e-04
# Epoch 73/100
# 42/42 [==============================] - 3s 69ms/step - loss: 2.9338e-04
# Epoch 74/100
# 42/42 [==============================] - 3s 67ms/step - loss: 2.5895e-04
# Epoch 75/100
# 42/42 [==============================] - 3s 67ms/step - loss: 2.6728e-04
# Epoch 76/100
# 42/42 [==============================] - 3s 68ms/step - loss: 2.3878e-04
# Epoch 77/100
# 42/42 [==============================] - 3s 67ms/step - loss: 2.5874e-04
# Epoch 78/100
# 42/42 [==============================] - 3s 68ms/step - loss: 2.4253e-04
# Epoch 79/100
# 42/42 [==============================] - 3s 68ms/step - loss: 2.4466e-04
# Epoch 80/100
# 42/42 [==============================] - 3s 68ms/step - loss: 2.4580e-04
# Epoch 81/100
# 42/42 [==============================] - 3s 67ms/step - loss: 2.4028e-04
# Epoch 82/100
# 42/42 [==============================] - 3s 68ms/step - loss: 2.7692e-04
# Epoch 83/100
# 42/42 [==============================] - 3s 68ms/step - loss: 2.1526e-04
# Epoch 84/100
# 42/42 [==============================] - 3s 67ms/step - loss: 2.0414e-04
# Epoch 85/100
# 42/42 [==============================] - 3s 69ms/step - loss: 2.4274e-04
# Epoch 86/100
# 42/42 [==============================] - 3s 67ms/step - loss: 2.4934e-04
# Epoch 87/100
# 42/42 [==============================] - 3s 68ms/step - loss: 2.5249e-04
# Epoch 88/100
# 42/42 [==============================] - 3s 68ms/step - loss: 2.3037e-04
# Epoch 89/100
# 42/42 [==============================] - 3s 68ms/step - loss: 2.2953e-04
# Epoch 90/100
# 42/42 [==============================] - 3s 71ms/step - loss: 2.3614e-04
# Epoch 91/100
# 42/42 [==============================] - 3s 69ms/step - loss: 1.9829e-04
# Epoch 92/100
# 42/42 [==============================] - 3s 69ms/step - loss: 2.4528e-04
# Epoch 93/100
# 42/42 [==============================] - 3s 70ms/step - loss: 2.6027e-04
# Epoch 94/100
# 42/42 [==============================] - 3s 70ms/step - loss: 2.4908e-04
# Epoch 95/100
# 42/42 [==============================] - 3s 68ms/step - loss: 3.8409e-04
# Epoch 96/100
# 42/42 [==============================] - 3s 66ms/step - loss: 2.8534e-04
# Epoch 97/100
# 42/42 [==============================] - 3s 67ms/step - loss: 2.3137e-04
# Epoch 98/100
# 42/42 [==============================] - 3s 67ms/step - loss: 2.4474e-04
# Epoch 99/100
# 42/42 [==============================] - 3s 66ms/step - loss: 2.5030e-04
# Epoch 100/100
# 42/42 [==============================] - 3s 67ms/step - loss: 2.2432e-04

# %%
plt.plot(model01.history['loss'])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
real_stock_price = df_test.iloc[: , 4:5].values

# %%
real_stock_price.shape
# Out:
# (486, 1)

# %%
dataset_total = pd.concat([df_train['adjclose'], df_test['adjclose']], axis=0)
inputs = dataset_total[len(dataset_total) - len(df_test) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
for i in range(60, 486):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
dataset_total.shape
# Out:
# (1886,)

# %%
predicted_stock_price = model.predict(X_test)
# Out:
# 14/14 [==============================] - 0s 34ms/step

# %%
predicted_stock_price = sc.inverse_transform(predicted_stock_price)

# %%
plt.figure(figsize=(12, 6))

plt.plot(real_stock_price, color='black', label='Apple Stock Price')
plt.plot(predicted_stock_price, color='red', label='Predicted Apple Stock Price')

plt.title('Apple Stock Price Prediction')
plt.xlabel('Time')
plt.xlabel('Apple Stock Price')
plt.legend()
plt.show()
